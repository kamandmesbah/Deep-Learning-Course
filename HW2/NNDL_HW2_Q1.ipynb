# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd gdrive/MyDrive/ai-ut/NNDL
# Out:
# [Errno 2] No such file or directory: 'gdrive/MyDrive/ai-ut/NNDL'
# /content

# %%
# %cd gdrive/MyDrive/NNDL
# Out:
# /content/gdrive/MyDrive/NNDL

# %%
# !unrar x "/content/gdrive/MyDrive/Untitled Folder/NN_HW2_Face_Emotion.rar" "/content/AffectNet/"
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
# Cannot open /content/gdrive/MyDrive/Untitled Folder/NN_HW2_Face_Emotion.rar
# No such file or directory
# No files to extract

# %%
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split

# Define paths
base_dir = 'AffectNet'
train_dir = os.path.join(base_dir, 'TRAIN')
tune_dir = os.path.join(base_dir, 'TUNE')

# Data augmentation configuration for training data
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    validation_split=0.2  # Splitting the training data into 80% train, 20% validation
)

# Data generator for tuning data (no augmentation, just normalization)
tune_datagen = ImageDataGenerator(rescale=1./255)

# Flow training images in batches of (for example, 32) using train_datagen generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),  # Resize images to 128x128
    batch_size=400,
    class_mode='categorical',  # Assuming categorical labels
    subset='training'  # Set as training data
    # ,shuffle=False
)

# Flow validation images in batches of 32 using train_datagen generator
validation_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(128, 128),
    batch_size=400,
    class_mode='categorical',
    subset='validation'  # Set as validation data
    # ,shuffle=False
)

# Flow tuning images in batches of 32 using tune_datagen generator
tune_generator = tune_datagen.flow_from_directory(
    tune_dir,
    target_size=(128, 128),
    batch_size=400,
    class_mode='categorical'
    # ,shuffle=False
)
# Out:
# Found 6409 images belonging to 8 classes.
# Found 1601 images belonging to 8 classes.
# Found 1600 images belonging to 8 classes.

# %%
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, BatchNormalization, Activation, Dropout,GaussianDropout

def AlexNet():
    model = Sequential()
    # CONV BLOCK 1
    model.add(Conv2D(16, (9, 9), input_shape=(128, 128, 3), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(GaussianDropout(0.2))
    # CONV BLOCK 2
    model.add(Conv2D(32, (7, 7), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(GaussianDropout(0.2))
    # CONV BLOCK 3
    model.add(Conv2D(64, (5, 5), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(GaussianDropout(0.2))
    # CONV BLOCK 4
    model.add(Conv2D(128, (3, 3), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(GaussianDropout(0.2))
    # CONV BLOCK 5
    model.add(Conv2D(128, (3, 3), padding='same', use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(GaussianDropout(0.2))
    # FLATTEN
    model.add(Flatten())
    # DENSE 1
    model.add(Dense(1024, use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    # DENSE 2
    model.add(Dense(1024, use_bias=False))
    model.add(BatchNormalization())
    model.add(Activation('relu'))
    model.add(Dropout(0.5))
    # OUTPUT
    model.add(Dense(8, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    # Summary of the model
    model.summary()

    return model

# %%
model = AlexNet()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 128, 128, 16)      3888
#
#  batch_normalization_7 (Bat  (None, 128, 128, 16)      64
#  chNormalization)
#
#  activation_7 (Activation)   (None, 128, 128, 16)      0
#
#  max_pooling2d_5 (MaxPoolin  (None, 64, 64, 16)        0
#  g2D)
#
#  gaussian_dropout_5 (Gaussi  (None, 64, 64, 16)        0
#  anDropout)
#
#  conv2d_6 (Conv2D)           (None, 64, 64, 32)        25088
#
#  batch_normalization_8 (Bat  (None, 64, 64, 32)        128
#  chNormalization)
#
#  activation_8 (Activation)   (None, 64, 64, 32)        0
#
#  max_pooling2d_6 (MaxPoolin  (None, 32, 32, 32)        0
#  g2D)
#
#  gaussian_dropout_6 (Gaussi  (None, 32, 32, 32)        0
#  anDropout)
#
#  conv2d_7 (Conv2D)           (None, 32, 32, 64)        51200
#
#  batch_normalization_9 (Bat  (None, 32, 32, 64)        256
#  chNormalization)
#
#  activation_9 (Activation)   (None, 32, 32, 64)        0
#
#  max_pooling2d_7 (MaxPoolin  (None, 16, 16, 64)        0
#  g2D)
#
#  gaussian_dropout_7 (Gaussi  (None, 16, 16, 64)        0
#  anDropout)
#
#  conv2d_8 (Conv2D)           (None, 16, 16, 128)       73728
#
#  batch_normalization_10 (Ba  (None, 16, 16, 128)       512
#  tchNormalization)
#
#  activation_10 (Activation)  (None, 16, 16, 128)       0
#
#  max_pooling2d_8 (MaxPoolin  (None, 8, 8, 128)         0
#  g2D)
#
#  gaussian_dropout_8 (Gaussi  (None, 8, 8, 128)         0
#  anDropout)
#
#  conv2d_9 (Conv2D)           (None, 8, 8, 128)         147456
#
#  batch_normalization_11 (Ba  (None, 8, 8, 128)         512
#  tchNormalization)
#
#  activation_11 (Activation)  (None, 8, 8, 128)         0
#
#  max_pooling2d_9 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  gaussian_dropout_9 (Gaussi  (None, 4, 4, 128)         0
#  anDropout)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 1024)              2097152
#
#  batch_normalization_12 (Ba  (None, 1024)              4096
#  tchNormalization)
#
#  activation_12 (Activation)  (None, 1024)              0
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 1024)              1048576
#
#  batch_normalization_13 (Ba  (None, 1024)              4096
#  tchNormalization)
#
#  activation_13 (Activation)  (None, 1024)              0
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 8)                 8200
#
# =================================================================
# Total params: 3464952 (13.22 MB)
# Trainable params: 3460120 (13.20 MB)
# Non-trainable params: 4832 (18.88 KB)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

# Assuming 'model' is your pre-defined Keras model

# Compile the model
# model.compile(optimizer=Adam(learning_rate=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-8), loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
initial_epochs = 25  # for example, set the number of epochs for initial training
history = model.fit(
    train_generator,
    epochs=initial_epochs,
    validation_data=validation_generator
)

# Now, let's fine-tune the model
# For fine-tuning, you might want to modify the learning rate, unfreeze some layers etc.
# This part depends on your specific model and approach
model.compile(optimizer=Adam(learning_rate=0.0001),  # Reduced learning rate for fine-tuning
              loss='categorical_crossentropy',
              metrics=['accuracy'])

fine_tune_epochs = 10  # Set the number of fine-tuning epochs
total_epochs = initial_epochs + fine_tune_epochs

# Fine-tune the model
fine_tune_history = model.fit(
    tune_generator,
    epochs=total_epochs,
    initial_epoch=history.epoch[-1],
    validation_data=validation_generator
)

# Save the model if necessary
model.save('path_to_my_model.h5')
# Out:
# Epoch 1/25
# 17/17 [==============================] - 70s 4s/step - loss: 2.6810 - accuracy: 0.1329 - val_loss: 2.4117 - val_accuracy: 0.1156
# Epoch 2/25
# 17/17 [==============================] - 57s 4s/step - loss: 2.5479 - accuracy: 0.1501 - val_loss: 3.7458 - val_accuracy: 0.1337
# Epoch 3/25
# 17/17 [==============================] - 55s 3s/step - loss: 2.4288 - accuracy: 0.1612 - val_loss: 3.5250 - val_accuracy: 0.1493
# Epoch 4/25
# 17/17 [==============================] - 54s 3s/step - loss: 2.3643 - accuracy: 0.1620 - val_loss: 2.8880 - val_accuracy: 0.1243
# Epoch 5/25
# 17/17 [==============================] - 53s 3s/step - loss: 2.3490 - accuracy: 0.1596 - val_loss: 2.9684 - val_accuracy: 0.1393
# Epoch 6/25
# 17/17 [==============================] - 54s 3s/step - loss: 2.2705 - accuracy: 0.1685 - val_loss: 2.7199 - val_accuracy: 0.1449
# Epoch 7/25
# 17/17 [==============================] - 56s 3s/step - loss: 2.2474 - accuracy: 0.1671 - val_loss: 2.5115 - val_accuracy: 0.1624
# Epoch 8/25
# 17/17 [==============================] - 54s 3s/step - loss: 2.2275 - accuracy: 0.1782 - val_loss: 2.1802 - val_accuracy: 0.1705
# Epoch 9/25
# 17/17 [==============================] - 53s 3s/step - loss: 2.1752 - accuracy: 0.1860 - val_loss: 2.2091 - val_accuracy: 0.1599
# Epoch 10/25
# 17/17 [==============================] - 65s 4s/step - loss: 2.1167 - accuracy: 0.2022 - val_loss: 2.1338 - val_accuracy: 0.1524
# Epoch 11/25
# 17/17 [==============================] - 55s 3s/step - loss: 2.1118 - accuracy: 0.2061 - val_loss: 2.0780 - val_accuracy: 0.1993
# Epoch 12/25
# 17/17 [==============================] - 52s 3s/step - loss: 2.0924 - accuracy: 0.2044 - val_loss: 2.0448 - val_accuracy: 0.1780
# Epoch 13/25
# 17/17 [==============================] - 53s 3s/step - loss: 2.0575 - accuracy: 0.2145 - val_loss: 2.0548 - val_accuracy: 0.1949
# Epoch 14/25
# 17/17 [==============================] - 53s 3s/step - loss: 2.0316 - accuracy: 0.2253 - val_loss: 2.1610 - val_accuracy: 0.1674
# Epoch 15/25
# 17/17 [==============================] - 53s 3s/step - loss: 2.0241 - accuracy: 0.2289 - val_loss: 2.0346 - val_accuracy: 0.1986
# Epoch 16/25
# 17/17 [==============================] - 55s 3s/step - loss: 2.0382 - accuracy: 0.2188 - val_loss: 2.0406 - val_accuracy: 0.1974
# Epoch 17/25
# 17/17 [==============================] - 53s 3s/step - loss: 1.9701 - accuracy: 0.2389 - val_loss: 2.1154 - val_accuracy: 0.1505
# Epoch 18/25
# 17/17 [==============================] - 54s 3s/step - loss: 1.9960 - accuracy: 0.2395 - val_loss: 2.1558 - val_accuracy: 0.1830
# Epoch 19/25
# 17/17 [==============================] - 52s 3s/step - loss: 1.9646 - accuracy: 0.2532 - val_loss: 2.0200 - val_accuracy: 0.2055
# Epoch 20/25
# 17/17 [==============================] - 55s 3s/step - loss: 1.9053 - accuracy: 0.2550 - val_loss: 2.0056 - val_accuracy: 0.2105
# Epoch 21/25
# 17/17 [==============================] - 53s 3s/step - loss: 1.9037 - accuracy: 0.2656 - val_loss: 1.9853 - val_accuracy: 0.2492
# Epoch 22/25
# 17/17 [==============================] - 64s 4s/step - loss: 1.8503 - accuracy: 0.2838 - val_loss: 1.8963 - val_accuracy: 0.2736
# Epoch 23/25
# 17/17 [==============================] - 53s 3s/step - loss: 1.8361 - accuracy: 0.2902 - val_loss: 2.0124 - val_accuracy: 0.2280
# Epoch 24/25
# 17/17 [==============================] - 54s 3s/step - loss: 1.8313 - accuracy: 0.2908 - val_loss: 2.0360 - val_accuracy: 0.2423
# Epoch 25/25
# 17/17 [==============================] - 53s 3s/step - loss: 1.8515 - accuracy: 0.2849 - val_loss: 1.8923 - val_accuracy: 0.2680
# Epoch 25/35
# 4/4 [==============================] - 300s 98s/step - loss: 2.0797 - accuracy: 0.2338 - val_loss: 1.8987 - val_accuracy: 0.2661
# Epoch 26/35
# 4/4 [==============================] - 15s 5s/step - loss: 2.0308 - accuracy: 0.2500 - val_loss: 1.9186 - val_accuracy: 0.2473
# Epoch 27/35
# 4/4 [==============================] - 15s 5s/step - loss: 1.9876 - accuracy: 0.2544 - val_loss: 1.9203 - val_accuracy: 0.2467
# Epoch 28/35
# 4/4 [==============================] - 15s 5s/step - loss: 1.9313 - accuracy: 0.2644 - val_loss: 1.9368 - val_accuracy: 0.2411
# Epoch 29/35
# 4/4 [==============================] - 14s 4s/step - loss: 1.8893 - accuracy: 0.2962 - val_loss: 1.9309 - val_accuracy: 0.2399
# Epoch 30/35
# 4/4 [==============================] - 15s 4s/step - loss: 1.9093 - accuracy: 0.2788 - val_loss: 1.9423 - val_accuracy: 0.2361
# Epoch 31/35
# 4/4 [==============================] - 15s 5s/step - loss: 1.8928 - accuracy: 0.2869 - val_loss: 1.9430 - val_accuracy: 0.2367
# Epoch 32/35
# 4/4 [==============================] - 15s 4s/step - loss: 1.8726 - accuracy: 0.2969 - val_loss: 1.9316 - val_accuracy: 0.2480
# Epoch 33/35
# 4/4 [==============================] - 14s 4s/step - loss: 1.8465 - accuracy: 0.2919 - val_loss: 1.9168 - val_accuracy: 0.2573
# Epoch 34/35
# 4/4 [==============================] - 15s 5s/step - loss: 1.8365 - accuracy: 0.2969 - val_loss: 1.9270 - val_accuracy: 0.2436
# Epoch 35/35
# 4/4 [==============================] - 14s 4s/step - loss: 1.8275 - accuracy: 0.3031 - val_loss: 1.9304 - val_accuracy: 0.2598
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

additional_epochs = 10
# Continue training the model
continued_history = model.fit(
    train_generator,
    epochs=additional_epochs+initial_epochs+20,
    initial_epoch=history.epoch[-1] + 1,
    validation_data=validation_generator
)

model.compile(optimizer=Adam(learning_rate=0.0001),  # Reduced learning rate for fine-tuning
              loss='categorical_crossentropy',
              metrics=['accuracy'])

additional_fine_tune_epochs = 5
# Fine-tune the model again
additional_fine_tune_history = model.fit(
    tune_generator,
    epochs=additional_fine_tune_epochs+total_epochs+10,
    initial_epoch=fine_tune_history.epoch[-1] + 1,
    validation_data=validation_generator
)

# Combine the history from the previous training session with the new one
# Note that 'history.history' is a dictionary with keys for each metric
# For each metric, extend the list with the values from the continued training
for key in history.history:
    history.history[key].extend(continued_history.history[key])

for key in fine_tune_history.history:
    fine_tune_history.history[key].extend(additional_fine_tune_history.history[key])
# Out:
# Epoch 26/55
# 17/17 [==============================] - 58s 3s/step - loss: 1.5141 - accuracy: 0.4216 - val_loss: 2.0759 - val_accuracy: 0.3154
# Epoch 27/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.5119 - accuracy: 0.4199 - val_loss: 1.6844 - val_accuracy: 0.3704
# Epoch 28/55
# 17/17 [==============================] - 63s 4s/step - loss: 1.4869 - accuracy: 0.4281 - val_loss: 1.7105 - val_accuracy: 0.4166
# Epoch 29/55
# 17/17 [==============================] - 51s 3s/step - loss: 1.4324 - accuracy: 0.4425 - val_loss: 1.8963 - val_accuracy: 0.3492
# Epoch 30/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.4408 - accuracy: 0.4445 - val_loss: 1.7017 - val_accuracy: 0.3641
# Epoch 31/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.4559 - accuracy: 0.4409 - val_loss: 1.9113 - val_accuracy: 0.2698
# Epoch 32/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.4247 - accuracy: 0.4450 - val_loss: 1.9756 - val_accuracy: 0.2555
# Epoch 33/55
# 17/17 [==============================] - 51s 3s/step - loss: 1.4130 - accuracy: 0.4594 - val_loss: 1.7480 - val_accuracy: 0.3791
# Epoch 34/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.4294 - accuracy: 0.4480 - val_loss: 1.7935 - val_accuracy: 0.3691
# Epoch 35/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.3985 - accuracy: 0.4634 - val_loss: 1.6864 - val_accuracy: 0.4260
# Epoch 36/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.4155 - accuracy: 0.4598 - val_loss: 1.8312 - val_accuracy: 0.3398
# Epoch 37/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.4730 - accuracy: 0.4297 - val_loss: 2.1041 - val_accuracy: 0.2879
# Epoch 38/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.4707 - accuracy: 0.4363 - val_loss: 1.9543 - val_accuracy: 0.3510
# Epoch 39/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.3941 - accuracy: 0.4636 - val_loss: 1.6508 - val_accuracy: 0.4179
# Epoch 40/55
# 17/17 [==============================] - 51s 3s/step - loss: 1.3807 - accuracy: 0.4592 - val_loss: 1.6527 - val_accuracy: 0.4510
# Epoch 41/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.4241 - accuracy: 0.4523 - val_loss: 1.6198 - val_accuracy: 0.4104
# Epoch 42/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.4416 - accuracy: 0.4409 - val_loss: 1.6783 - val_accuracy: 0.3985
# Epoch 43/55
# 17/17 [==============================] - 51s 3s/step - loss: 1.3703 - accuracy: 0.4693 - val_loss: 1.6624 - val_accuracy: 0.4397
# Epoch 44/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.3328 - accuracy: 0.4973 - val_loss: 1.5322 - val_accuracy: 0.4722
# Epoch 45/55
# 17/17 [==============================] - 51s 3s/step - loss: 1.3626 - accuracy: 0.4760 - val_loss: 1.6308 - val_accuracy: 0.4147
# Epoch 46/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.3648 - accuracy: 0.4787 - val_loss: 1.6284 - val_accuracy: 0.4291
# Epoch 47/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.3665 - accuracy: 0.4770 - val_loss: 1.5622 - val_accuracy: 0.4728
# Epoch 48/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.3170 - accuracy: 0.4874 - val_loss: 1.6531 - val_accuracy: 0.3998
# Epoch 49/55
# 17/17 [==============================] - 51s 3s/step - loss: 1.4037 - accuracy: 0.4589 - val_loss: 1.7788 - val_accuracy: 0.3435
# Epoch 50/55
# 17/17 [==============================] - 54s 3s/step - loss: 1.3334 - accuracy: 0.4871 - val_loss: 1.6265 - val_accuracy: 0.4647
# Epoch 51/55
# 17/17 [==============================] - 52s 3s/step - loss: 1.3427 - accuracy: 0.4856 - val_loss: 1.5116 - val_accuracy: 0.4622
# Epoch 52/55
# 17/17 [==============================] - 63s 4s/step - loss: 1.3041 - accuracy: 0.5043 - val_loss: 1.5916 - val_accuracy: 0.4360
# Epoch 53/55
# 17/17 [==============================] - 63s 4s/step - loss: 1.3054 - accuracy: 0.5020 - val_loss: 1.4681 - val_accuracy: 0.4834
# Epoch 54/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.2961 - accuracy: 0.5057 - val_loss: 1.6990 - val_accuracy: 0.4503
# Epoch 55/55
# 17/17 [==============================] - 53s 3s/step - loss: 1.2807 - accuracy: 0.5030 - val_loss: 1.5571 - val_accuracy: 0.4678
# Epoch 36/50
# 4/4 [==============================] - 30s 8s/step - loss: 1.9164 - accuracy: 0.3900 - val_loss: 1.5480 - val_accuracy: 0.4697
# Epoch 37/50
# 4/4 [==============================] - 15s 5s/step - loss: 1.8694 - accuracy: 0.3969 - val_loss: 1.5380 - val_accuracy: 0.4853
# Epoch 38/50
# 4/4 [==============================] - 15s 5s/step - loss: 1.8436 - accuracy: 0.3969 - val_loss: 1.5319 - val_accuracy: 0.4828
# Epoch 39/50
# 4/4 [==============================] - 15s 5s/step - loss: 1.7794 - accuracy: 0.3975 - val_loss: 1.5525 - val_accuracy: 0.4591
# Epoch 40/50
# 4/4 [==============================] - 15s 5s/step - loss: 1.7583 - accuracy: 0.4119 - val_loss: 1.5632 - val_accuracy: 0.4666
# Epoch 41/50
# 4/4 [==============================] - 15s 5s/step - loss: 1.6864 - accuracy: 0.4175 - val_loss: 1.5753 - val_accuracy: 0.4753
# Epoch 42/50
# 4/4 [==============================] - 14s 4s/step - loss: 1.6656 - accuracy: 0.4200 - val_loss: 1.6322 - val_accuracy: 0.4535
# Epoch 43/50
# 4/4 [==============================] - 15s 5s/step - loss: 1.6315 - accuracy: 0.4369 - val_loss: 1.6412 - val_accuracy: 0.4379
# Epoch 44/50
# 4/4 [==============================] - 15s 5s/step - loss: 1.6394 - accuracy: 0.4244 - val_loss: 1.6514 - val_accuracy: 0.4360
# Epoch 45/50
# 4/4 [==============================] - 15s 4s/step - loss: 1.6026 - accuracy: 0.4156 - val_loss: 1.6482 - val_accuracy: 0.4422
# Epoch 46/50
# 4/4 [==============================] - 24s 8s/step - loss: 1.5951 - accuracy: 0.4363 - val_loss: 1.6509 - val_accuracy: 0.4335
# Epoch 47/50
# 4/4 [==============================] - 14s 4s/step - loss: 1.5700 - accuracy: 0.4269 - val_loss: 1.6763 - val_accuracy: 0.4341
# Epoch 48/50
# 4/4 [==============================] - 24s 8s/step - loss: 1.5500 - accuracy: 0.4487 - val_loss: 1.6697 - val_accuracy: 0.4335
# Epoch 49/50
# 4/4 [==============================] - 14s 4s/step - loss: 1.5374 - accuracy: 0.4462 - val_loss: 1.6746 - val_accuracy: 0.4260
# Epoch 50/50
# 4/4 [==============================] - 14s 4s/step - loss: 1.5153 - accuracy: 0.4556 - val_loss: 1.6787 - val_accuracy: 0.4266

# %%
train_generator.shuffle = False
validation_generator.shuffle = False

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, precision_recall_fscore_support, confusion_matrix
from sklearn.preprocessing import label_binarize
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint

# Plotting Loss and Accuracy curves
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curves')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curves')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
# Evaluate the model on the validation set
validation_results = model.evaluate(validation_generator)

# Get predictions on the validation set
validation_predictions = model.predict(validation_generator)
# Out:
# 5/5 [==============================] - 11s 2s/step - loss: 1.6673 - accuracy: 0.4166
# 5/5 [==============================] - 11s 2s/step

# %%
# Plot ROC curves for each class
classes = ["anger", "contempt", "disgust", "fear", "happy", "neutral", "sad", "surprise"]
num_classes = len(classes)

validation_labels = label_binarize(validation_generator.classes, classes=[0,1,2,3,4,5,6,7])

plt.figure(figsize=(10, 8))
for i in range(num_classes):
    fpr, tpr, _ = roc_curve(validation_labels[:, i], validation_predictions[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'{classes[i]} (AUC = {roc_auc:.2f})')

plt.plot([0, 1], [0, 1], linestyle='--', color='gray', label='Random')
plt.title('ROC Curves for Each Class')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.legend()
plt.show()

# %%
# Calculate precision, recall, and F1 for each class
validation_pred_classes = validation_predictions.argmax(axis=-1)
validation_true_classes = validation_generator.classes

precision, recall, f1, _ = precision_recall_fscore_support(validation_true_classes, validation_pred_classes)

for i in range(num_classes):
    print(f'Class {classes[i]}\t - Precision: {precision[i]:.4f}, Recall: {recall[i]:.4f}, F1 Score: {f1[i]:.4f}')
# Out:
# Class anger	 - Precision: 0.5844, Recall: 0.2250, F1 Score: 0.3249
# Class contempt	 - Precision: 0.4091, Recall: 0.2700, F1 Score: 0.3253
# Class disgust	 - Precision: 0.5000, Recall: 0.2250, F1 Score: 0.3103
# Class fear	 - Precision: 0.5000, Recall: 0.5700, F1 Score: 0.5327
# Class happy	 - Precision: 0.4499, Recall: 0.9154, F1 Score: 0.6033
# Class neutral	 - Precision: 0.3496, Recall: 0.7150, F1 Score: 0.4696
# Class sad	 - Precision: 0.4444, Recall: 0.2600, F1 Score: 0.3281
# Class surprise	 - Precision: 0.5036, Recall: 0.3500, F1 Score: 0.4130

# %%
# Plot confusion matrix
conf_matrix = confusion_matrix(validation_true_classes, validation_pred_classes)
plt.figure(figsize=(8, 6))
plt.imshow(conf_matrix, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
tick_marks = range(num_classes)
plt.xticks(tick_marks, classes)
plt.yticks(tick_marks, classes)
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
